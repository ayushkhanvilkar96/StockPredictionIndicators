# %%
import pandas as pd
from stockstats import StockDataFrame as Sdf

data   = pd.read_csv('AAPL.csv')

stock  = Sdf.retype(data)
pd.options.mode.chained_assignment = None 


# volume delta against previous day
#stock['volume_delta'][-9:]

# MACD
#stock['macd']

# MACD signal line
#stock['macds']

# MACD histogram
#stock['macdh']

# 6 days RSI
#stock['rsi_6']
# 12 days RSI
#stock['rsi_12']

# TR (true range)
#stock['tr']

# ATR (Average True Range)
#stock['atr']

# DMA, difference of 10 and 50 moving average
#stock['dma']

# DMI
# +DI, default to 14 days
#stock['pdi']

# -DI, default to 14 days
#stock['mdi']

# DX, default to 14 days of +DI and -DI
#stock['dx']

# ADX, 6 days SMA of DX, same as stock['dx_6_ema']
#stock['adx']

# ADXR, 6 days SMA of ADX, same as stock['adx_6_ema']
#stock['adxr']

# TRIX, default to 12 days
#stock['trix']
# MATRIX is the simple moving average of TRIX
#stock['trix_9_sma']

# VR, default to 26 days
#stock['vr']
# MAVR is the simple moving average of VR
#stock['vr_6_sma']

rsi_6=stock['rsi_6'][-100:]
print(type(rsi_6))
print(rsi_6)
# Out:
# <class 'pandas.core.series.Series'>
# date
# 2017-11-08    87.816570
# 2017-11-09    84.599970
# 2017-11-10    73.710284
# 2017-11-13    67.663952
# 2017-11-14    49.395769
# 2017-11-15    38.638729
# 2017-11-16    50.257427
# 2017-11-17    45.405344
# 2017-11-20    44.483156
# 2017-11-21    61.792650
# 2017-11-22    68.566293
# 2017-11-24    68.602971
# 2017-11-27    61.073022
# 2017-11-28    52.984171
# 2017-11-29    33.977378
# 2017-11-30    48.587846
# 2017-12-01    44.590799
# 2017-12-04    38.632003
# 2017-12-05    37.854972
# 2017-12-06    34.569637
# 2017-12-07    37.759320
# 2017-12-08    38.340932
# 2017-12-11    64.569214
# 2017-12-12    56.145107
# 2017-12-13    59.839840
# 2017-12-14    59.313801
# 2017-12-15    70.284490
# 2017-12-18    79.548818
# 2017-12-19    61.805572
# 2017-12-20    60.177843
#                 ...
# 2018-02-21    63.365846
# 2018-02-22    67.293347
# 2018-02-23    74.244648
# 2018-02-26    80.111673
# 2018-02-27    76.611222
# 2018-02-28    74.785776
# 2018-03-01    56.212949
# 2018-03-02    60.749440
# 2018-03-05    63.064397
# 2018-03-06    61.985559
# 2018-03-07    50.624043
# 2018-03-08    60.693053
# 2018-03-09    71.711148
# 2018-03-12    76.278269
# 2018-03-13    63.839306
# 2018-03-14    54.512851
# 2018-03-15    55.581620
# 2018-03-16    51.246771
# 2018-03-19    36.498662
# 2018-03-20    36.222731
# 2018-03-21    22.635162
# 2018-03-22    17.761585
# 2018-03-23    12.530633
# 2018-03-26    48.780199
# 2018-03-27    38.068921
# 2018-03-28    34.276757
# 2018-03-29    39.344337
# 2018-04-02    36.487670
# 2018-04-03    44.063904
# 2018-04-04    55.940127
# Name: rsi_6, dtype: float64
