# %%
import pandas as pd
from stockstats import StockDataFrame as Sdf
import matplotlib.pyplot as plt

data   = pd.read_csv('AAPL.csv')

stock  = Sdf.retype(data)
pd.options.mode.chained_assignment = None 

rsi_12=stock['rsi_12'][-14:]
#print(type(rsi_12))
rsi_100=rsi_12.tolist()
rsi_100 = list(map(int, rsi_100))
print(rsi_100)

plt.plot(rsi_100)
plt.show()
# Out:
# [58, 56, 49, 48, 39, 35, 29, 48, 41, 38, 41, 40, 43, 50]
